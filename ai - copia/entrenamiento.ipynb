# %%
import os
os.environ.pop('CUDA_VISIBLE_DEVICES', None)

from ultralytics import YOLO

model = YOLO('yolov8n.pt')

results = model.train(
    data=r'D:\Personal\Descargas\Arduinitos-main\Arduinitos-main\ai\data.yaml',
    epochs=30,
    imgsz=640,
    batch=16,
    device='cpu'
)
# Out:
# Ultralytics 8.4.46  Python-3.13.13 torch-2.11.0+cpu CPU (Intel Core i5-7200U 2.50GHz)
# ...

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\USUARIO\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe
